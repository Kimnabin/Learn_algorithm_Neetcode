# %% [markdown]
# # Container with most water
#
# You are given an integer array height of length n. There are n vertical lines drawn such that the two endpoints of the ith line are (i, 0) and (i, height[i]).
#
# Find two lines that together with the x-axis form a container, such that the container contains the most water.
#
# Return the maximum amount of water a container can store.
#
# Notice that you may not slant the container.
#
#
#
# Example 1:
#
#
#     Input: height = [1,8,6,2,5,4,8,3,7]
#     Output: 49
#
# Explanation:
#     The above vertical lines are represented by array [1,8,6,2,5,4,8,3,7]. In this case, the max area of water (blue section) the container can contain is 49.
#
# Example 2:
#
#     Input: height = [1,1]
#     Output: 1
#
#
# Constraints:
#
#     n == height.length
#     2 <= n <= 105
#     0 <= height[i] <= 104

# %%
from typing import List


class Solution:
    def maxArea(self, height: List[int]) -> int:
        left = 0
        right = len(height) - 1
        maxArea = 0

        while left < right:
            currentArea = min(height[left], height[right]) * (right - left)
            maxArea = max(maxArea, currentArea)

            if height[left] < height[right]:
                left += 1
            else:
                right -= 1

        return maxArea
    
sol = Solution()
print(sol.maxArea([1,8,6,2,5,4,8,3,7])) # 49
# Out:
# 49

# %% [markdown]
# Giải pháp của bạn cho bài toán "Container With Most Water" sử dụng phương pháp hai con trỏ để tìm diện tích lớn nhất giữa hai thanh. Đây là một cách tiếp cận hiệu quả với độ phức tạp thời gian \(O(n)\). Dưới đây là một giải thích chi tiết và một số điểm cần lưu ý.
#
# ### Giải thích mã
#
# 1. **Khởi tạo con trỏ**:
#    - `left` bắt đầu từ vị trí đầu tiên của mảng.
#    - `right` bắt đầu từ vị trí cuối cùng của mảng.
#    - `maxArea` được khởi tạo bằng 0 để lưu trữ diện tích lớn nhất tìm được.
#
# 2. **Duyệt qua mảng**:
#    - Trong khi `left` nhỏ hơn `right`, tính diện tích của nước chứa giữa hai con trỏ:
#      - `currentArea = min(height[left], height[right]) * (right - left)`: Diện tích bằng chiều cao ngắn hơn giữa hai con trỏ nhân với khoảng cách giữa chúng.
#    - Cập nhật `maxArea` nếu `currentArea` lớn hơn giá trị hiện tại của `maxArea`.
#    - Di chuyển con trỏ:
#      - Nếu `height[left]` nhỏ hơn `height[right]`, di chuyển con trỏ `left` sang phải.
#      - Ngược lại, di chuyển con trỏ `right` sang trái.
#
# 3. **Trả về kết quả**:
#    - Sau khi duyệt hết mảng, trả về `maxArea` là diện tích lớn nhất tìm được.
#
# ### Mã đã được tối ưu và giải thích
#
# ```python
# from typing import List
#
# class Solution:
#     def maxArea(self, height: List[int]) -> int:
#         left = 0
#         right = len(height) - 1
#         maxArea = 0
#
#         while left < right:
#             # Tính diện tích hiện tại
#             currentArea = min(height[left], height[right]) * (right - left)
#             # Cập nhật diện tích lớn nhất
#             maxArea = max(maxArea, currentArea)
#
#             # Di chuyển con trỏ
#             if height[left] < height[right]:
#                 left += 1
#             else:
#                 right -= 1
#
#         return maxArea
#
# # Khởi tạo đối tượng Solution
# sol = Solution()
#
# # Gọi hàm maxArea và in kết quả
# print(sol.maxArea([1, 8, 6, 2, 5, 4, 8, 3, 7]))  # Kết quả mong đợi: 49
# ```
#
# ### Kết quả
#
# Khi bạn chạy đoạn mã trên, bạn sẽ nhận được kết quả:
#
# ```python
# 49
# ```
#
# ### Lưu ý
#
# 1. **Hiệu suất**: Phương pháp hai con trỏ này đảm bảo độ phức tạp thời gian \(O(n)\) vì mỗi phần tử trong mảng chỉ được duyệt qua một lần.
# 2. **Tính đúng đắn**: Bằng cách di chuyển con trỏ ngắn hơn, bạn tối đa hóa khả năng tìm diện tích lớn hơn trong các bước tiếp theo.
# 3. **Tính rõ ràng**: Mã dễ đọc và dễ hiểu, phù hợp với cả những người mới bắt đầu.
#
# Phương pháp này là một trong những cách hiệu quả nhất để giải quyết bài toán "Container With Most Water".
